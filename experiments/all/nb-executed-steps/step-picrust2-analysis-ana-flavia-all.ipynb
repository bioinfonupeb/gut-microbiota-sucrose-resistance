# %% [markdown]
# ### STEP : PICRUST2 Analysis
#
#
#
# #### Example
#
# - [PICRUST2 tutorial](https://github.com/picrust/picrust2/wiki/q2-picrust2-Tutorial)
# - [Limitations](https://github.com/picrust/picrust2/wiki/Key-Limitations)
#
#
# #### Methods
# - [composition](https://docs.qiime2.org/2022.8/plugins/available/composition/)

# %% [markdown]
# ## Setup and settings

# %%
# Importing packages
import os
import biom
import pandas as pd
from qiime2 import Artifact
from qiime2 import Visualization
from qiime2 import Metadata

from qiime2.plugins.feature_table.visualizers import summarize
from qiime2.plugins.diversity.pipelines import core_metrics

from picrust2.pipeline import full_pipeline
from picrust2.default import (default_ref_dir, default_tables, default_regroup_map, default_pathway_map)
from qiime2.plugins import picrust2
from qiime2.plugins.feature_table.methods import filter_samples
from qiime2.plugins.feature_table.methods import filter_seqs

# %matplotlib inline

# %% [markdown]
# ### Receiving the parameters
#
# The following cell can receive parameters using the [papermill](https://papermill.readthedocs.io/en/latest/) tool.

# %%
metadata_file = '/home/lauro/nupeb/rede-micro/redemicro-miliane-nutri/data/raw/metadata/miliane-metadata-CxAC.tsv'
base_dir = os.path.join('/', 'home', 'lauro', 'nupeb', 'rede-micro', 'redemicro-miliane-nutri')
experiment_name = 'miliane-CxAC-trim'
class_col = 'group-id'
replace_files = False

# %%
# Parameters
base_dir = "/mnt/nupeb/rede-micro/redemicro-ana-flavia-nutri"
class_col = "group-id"
classifier_file = "/mnt/nupeb/rede-micro/datasets/16S_classifiers_qiime2/silva-138-99-nb-classifier.qza"
experiment_name = "ana-flavia-all"
manifest_file = "/mnt/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/manifest-all-ana.csv"
metadata_file = "/mnt/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/metadata-all-ana.tsv"
overlap = 12
phred = 20
replace_files = False
threads = 6
top_n = 20
trim = {"forward_primer": "CCTACGGGRSGCAGCAG", "overlap": 8, "reverse_primer": "GGACTACHVGGGTWTCTAAT"}
trunc_f = 0
trunc_r = 0

# %%
experiment_folder = os.path.abspath(os.path.join(base_dir, 'experiments', experiment_name))
img_folder = os.path.abspath(os.path.join(experiment_folder, 'imgs'))

# %% [markdown]
# ### Defining names, paths and flags

# %%
# QIIME2 Artifacts folder
qiime_folder = os.path.join(experiment_folder, 'qiime-artifacts')

# Input - DADA2 Artifacts
dada2_tabs_path = os.path.join(qiime_folder, 'dada2-tabs.qza')
dada2_reqs_path = os.path.join(qiime_folder, 'dada2-reps.qza')

# PICRUST@ folder
picrust2_folder = os.path.abspath(os.path.join(experiment_folder, 'picrust2'))

# Create path if it not exist
if not os.path.isdir(picrust2_folder):
    os.makedirs(picrust2_folder)
    print(f'New picrust2-artifacts folder path created: {picrust2_folder}')
# Out:
# New picrust2-artifacts folder path created: /mnt/nupeb/rede-micro/redemicro-ana-flavia-nutri/experiments/ana-flavia-all/picrust2

# %%
# Define paths for metagenome function artifacts
ec_path = os.path.join(picrust2_folder, 'ec-pred-metagen.qza')
ko_path = os.path.join(picrust2_folder, 'ko-pred-metagen.qza')
pathway_path = os.path.join(picrust2_folder, 'pathway-abundance.qza')

# Define paths for metagenome function visualization artifacts
ec_viz_path = ec_path[:-1]+'v'
ko_viz_path = ko_path[:-1]+'v'
pathway_viz_path = pathway_path[:-1]+'v'

# Define paths for biom -> tsv files (function X sample)
pathway_fpath = os.path.join(picrust2_folder, 'pathway.tsv')
ec_fpath = os.path.join(picrust2_folder, 'ec.tsv')
ko_fpath = os.path.join(picrust2_folder, 'ko.tsv')

# Define paths for biom -> tsv files (function X sample) - with descriptions
pathway_desc_fpath = os.path.join(picrust2_folder, 'pathway-desc.tsv')
ec_desc_fpath = os.path.join(picrust2_folder, 'ec-desc.tsv')
ko_desc_fpath = os.path.join(picrust2_folder, 'ko-desc.tsv')

# %% [markdown]
# ## Step execution
#
# ### Load input files
#
# This Step import the QIIME2 `FeatureTable[Frequency]` Artifact and the `Metadata` file.

# %%
#Load Metadata
metadata_qa = Metadata.load(metadata_file)

#Load FeatureTable[Frequency]
tabs = Artifact.load(dada2_tabs_path)

#Load FeatureTable[Sequence]
seqs = Artifact.load(dada2_reqs_path)

# %%
# Filter FeatureTable[Frequency | RelativeFrequency | PresenceAbsence | Composition] based on Metadata sample ID values
tabs = filter_samples(
    table=tabs,
    metadata=metadata_qa,
).filtered_table
# Filter SampleData[SequencesWithQuality | PairedEndSequencesWithQuality | JoinedSequencesWithQuality] based on Metadata sample ID values; returns FeatureData[Sequence | AlignedSequence]
seqs = filter_seqs(
    data=seqs,
    table=tabs,
).filtered_data

# %% [markdown]
# ### Execute full pipelie
#
# The entire PICRUSt2 pipeline will be run using a single method, called `picrust2.methods.full_pipeline`. This method will run each of the 4 key steps:
#
# 1. sequence placement
# 2. hidden-state prediction of genomes
# 3. metagenome prediction
# 4. pathway-level predictions.
#
# More information on [Documentation](https://github.com/picrust/picrust2/wiki/Full-pipeline-script).

# %%
need_pipeline = replace_files
need_pipeline |= not (os.path.isfile(ec_path) and os.path.isfile(ko_path) and os.path.isfile(pathway_path))
if need_pipeline:
    results = picrust2.methods.full_pipeline(
        table=tabs, 
        seq=seqs, 
        threads=6, 
        placement_tool='sepp',
        hsp_method='pic', 
        max_nsti=2,
        highly_verbose=True
    )
    ec_metagenome = results.ec_metagenome
    ko_metagenome = results.ko_metagenome
    pathway_abundance = results.pathway_abundance
else:
    ec_metagenome = Artifact.load(ec_path)
    ko_metagenome = Artifact.load(ko_path)
    pathway_abundance = Artifact.load(pathway_path)
# Out:
# 1885 of 1885 sequence ids overlap between input table and FASTA.
#
# Placing sequences onto reference tree
# place_seqs.py --study_fasta /tmp/tmp5cdhtmw1/seqs.fna --ref_dir /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref --out_tree /tmp/tmp5cdhtmw1/picrust2_out/out.tre --processes 6 --intermediate /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs --min_align 0.8 --chunk_size 5000 --placement_tool sepp --verbose
#                                               ....      ....
#                                              '' '||.   .||'
#                                                   ||  ||
#                                                   '|.|'
#      ...'   ....   ... ...  ... ...   ....        .|'|.
#     |  ||  '' .||   ||'  ||  ||'  || '' .||      .|'  ||
#      |''   .|' ||   ||    |  ||    | .|' ||     .|'|.  ||
#     '....  '|..'|'. ||...'   ||...'  '|..'|.    '||'    ||:.
#     '....'          ||       ||
#                    ''''     ''''   v0.8.5 (c) 2017-2024
#                                    by Lucas Czech and Pierre Barbera
#
# Invocation:                        gappa examine graft --jplace-path /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json --fully-resolve --out-dir /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out
# Command:                           gappa examine graft
#
# Input:
#   --jplace-path                    /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json
#
# Settings:
#   --fully-resolve                  true
#   --name-prefix
#
# Output:
#   --out-dir                        /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out
#   --file-prefix
#   --file-suffix
#
# Newick Tree Output:
#   --newick-tree-quote-invalid-chars
#                                    false
#
# Global Options:
#   --allow-file-overwriting         false
#   --verbose                        false
#   --threads                        10
#   --log-file
#
# Run the following command to get the references that need to be cited:
# `gappa tools citation Czech2020-genesis-and-gappa`
#
# Started 2024-11-04 20:31:28
#
# Found 1 jplace file
#
# Finished 2024-11-04 20:31:29
# hmmalign --trim --dna --mapali /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.fna --informat FASTA -o /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/query_align.stockholm /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.hmm /tmp/tmp5cdhtmw1/seqs.fna
#
# Warning - 1 input sequences aligned poorly to reference sequences (--min_align option specified a minimum proportion of 0.8 aligning to reference sequences). These input sequences will not be placed and will be excluded from downstream steps.
#
# This is the set of poorly aligned input sequences to be excluded: 6fed430d2c42021ed5fa531745f38fba
#
# Raw input sequences ranged in length from 253 to 430
#
# run_sepp.py --tree /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.tre --raxml /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info --cpu 6 --molecule dna --outdir /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out -seed 297834 --alignment /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.fna --fragment /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/study_seqs_filtered.fasta
# [20:28:43] config.py (line 370):     INFO: Seed number: 297834
# [20:28:43] algorithm.py (line 267):     INFO: Reading input alignment: <_io.TextIOWrapper name='/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.fna' mode='r' encoding='UTF-8'>
# [20:28:43] algorithm.py (line 274):     INFO: Reading input tree: <_io.TextIOWrapper name='/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.tre' mode='r' encoding='UTF-8'>
# [20:28:44] algorithm.py (line 247):     INFO: Decomposition Sizes are set to alignment: 2000 placement: 2000
# [20:28:45] exhaustive.py (line 351):     INFO: Breaking into 16 placement subsets.
# [20:28:46] exhaustive.py (line 398):     INFO: Breaking into 16 alignment subsets.
# [20:28:46] filemgr.py (line 129):     INFO: Root temp directory built: /tmp/sepp/output.1m8v3xwz
# [20:28:46] exhaustive.py (line 413):     INFO: Breaking each alignment subset into 3 fragment chunks.
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_4/A_4_0/hmmbuild.input.vcpw49he.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_0/A_0_0/hmmbuild.input.addarrmd.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.input.lucl6kr1.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.input.8let4h61.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_2/A_2_0/hmmbuild.input.vezyhil4.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_3/A_3_0/hmmbuild.input.wb78gx3f.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.input.30ndmgra.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.input.qz_2ez75.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.input.w1xm8f8n.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.input.h8ftduuq.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_11/A_11_0/hmmbuild.input.5vshhbvg.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.input.e19975p0.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.input.ve7p78rf.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.input.tyqd2jjt.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.input.kdm4ox6b.fasta
# [20:28:49] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/hmmbuild.input.rvl9n1vi.fasta
# [20:28:59] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_4/A_4_0/hmmbuild.model.00fc0dys, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_4/A_4_0/FC_4_0_0/hmmsearch.results.xvft0mu7
# [20:28:59] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_4/A_4_0/hmmbuild.model.00fc0dys, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_4/A_4_0/FC_4_0_1/hmmsearch.results.u7potnxi
# [20:29:00] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_0/A_0_0/hmmbuild.model.c22weon2, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_0/A_0_0/FC_0_0_1/hmmsearch.results.2b0xv2k1
# [20:29:00] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_4/A_4_0/hmmbuild.model.00fc0dys, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_4/A_4_0/FC_4_0_2/hmmsearch.results.4d3u7zcj
# [20:29:00] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_0/A_0_0/hmmbuild.model.c22weon2, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_0/A_0_0/FC_0_0_0/hmmsearch.results.emtcw40b
# [20:29:00] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_0/A_0_0/hmmbuild.model.c22weon2, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_0/A_0_0/FC_0_0_2/hmmsearch.results.o0cr7gvx
# [20:29:09] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.model.1pt7yua_, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_0/hmmsearch.results.dkvr0jqv
# [20:29:09] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.model.1pt7yua_, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_1/hmmsearch.results.eiuaeqw3
# [20:29:10] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.model.n2zmw0v8, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_0/hmmsearch.results.jwkuqtsl
# [20:29:10] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.model.1pt7yua_, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_2/hmmsearch.results.wedin3pd
# [20:29:10] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.model.n2zmw0v8, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_2/hmmsearch.results.0k9e9l2x
# [20:29:10] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.model.n2zmw0v8, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_1/hmmsearch.results.2qspq9z4
# [20:29:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_2/A_2_0/hmmbuild.model.v4h54t3a, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_2/A_2_0/FC_2_0_0/hmmsearch.results.09uqar5a
# [20:29:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_2/A_2_0/hmmbuild.model.v4h54t3a, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_2/A_2_0/FC_2_0_1/hmmsearch.results.13m34zc_
# [20:29:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_2/A_2_0/hmmbuild.model.v4h54t3a, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_2/A_2_0/FC_2_0_2/hmmsearch.results.hr43390v
# [20:29:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_3/A_3_0/hmmbuild.model.2x4p24o8, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_3/A_3_0/FC_3_0_0/hmmsearch.results.cg5vz5_p
# [20:29:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_3/A_3_0/hmmbuild.model.2x4p24o8, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_3/A_3_0/FC_3_0_2/hmmsearch.results.pn3jaj7h
# [20:29:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_3/A_3_0/hmmbuild.model.2x4p24o8, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_3/A_3_0/FC_3_0_1/hmmsearch.results.9r4qvbfg
# [20:29:30] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.model.p1r0xwcx, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_0/hmmsearch.results.bhfcumka
# [20:29:30] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.model.p1r0xwcx, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_1/hmmsearch.results.cvqkjd21
# [20:29:30] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.model.p1r0xwcx, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_2/hmmsearch.results.1b6pfjls
# [20:29:30] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.model.hok6y546, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_0/hmmsearch.results.o_ux566a
# [20:29:30] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.model.hok6y546, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_1/hmmsearch.results.oxu3vl0e
# [20:29:30] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.model.hok6y546, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_2/hmmsearch.results.942014cj
# [20:29:40] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.model.t7vh54ez, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_0/hmmsearch.results.6pmkr0nt
# [20:29:40] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.model.t7vh54ez, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_1/hmmsearch.results.socmbiby
# [20:29:41] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.model.zs89dovw, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_0/hmmsearch.results.21k5j8rv
# [20:29:41] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.model.t7vh54ez, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_2/hmmsearch.results.mgkdcmev
# [20:29:41] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.model.zs89dovw, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_1/hmmsearch.results.i1v_o13i
# [20:29:41] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.model.zs89dovw, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_2/hmmsearch.results.hplkzpnp
# [20:29:50] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_11/A_11_0/hmmbuild.model.e7ye3plb, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_11/A_11_0/FC_11_0_0/hmmsearch.results.1uwa9u9c
# [20:29:51] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_11/A_11_0/hmmbuild.model.e7ye3plb, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_11/A_11_0/FC_11_0_1/hmmsearch.results.0g4vz8hu
# [20:29:51] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.model.cow4xr2p, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_0/hmmsearch.results.74kotd3j
# [20:29:51] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_11/A_11_0/hmmbuild.model.e7ye3plb, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_11/A_11_0/FC_11_0_2/hmmsearch.results.xdk68ig8
# [20:29:51] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.model.cow4xr2p, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_1/hmmsearch.results.n3740ae_
# [20:29:51] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.model.cow4xr2p, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_2/hmmsearch.results.a8txab1f
# [20:30:01] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.model.x2_393mh, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_0/hmmsearch.results.56tn0evy
# [20:30:01] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.model.x2_393mh, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_1/hmmsearch.results.qvvdriem
# [20:30:01] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.model.x2_393mh, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_2/hmmsearch.results.w08vnh5z
# [20:30:01] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.model.fdu3v2if, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_0/hmmsearch.results.ean0lurt
# [20:30:01] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.model.fdu3v2if, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_1/hmmsearch.results.o9rsiass
# [20:30:01] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.model.fdu3v2if, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_2/hmmsearch.results.a2u8ms6l
# [20:30:11] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.model.xlm77_kl, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_0/hmmsearch.results.bpckrbml
# [20:30:11] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.model.xlm77_kl, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_1/hmmsearch.results.9shg9o8a
# [20:30:11] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.model.xlm77_kl, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_2/hmmsearch.results.4y1n7voc
# [20:30:11] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/hmmbuild.model.x9yk1wsh, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_0vqwsq730.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/FC_15_0_0/hmmsearch.results.dz7oo5at
# [20:30:11] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/hmmbuild.model.x9yk1wsh, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_1n2i14fqh.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/FC_15_0_1/hmmsearch.results.ce3tj1t_
# [20:30:11] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/hmmbuild.model.x9yk1wsh, fragments:/tmp/sepp/output.1m8v3xwz/fragment_chunks/fragment_chunk_2n_0osc7c.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/FC_15_0_2/hmmsearch.results.ggli93cg
# [20:30:12] exhaustive.py (line 81):  WARNING: Fragments [] are not scored against any subset
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_0.
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_2.
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.model.1pt7yua_, fragments:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_2/hmmalign.frag.vsyo_ebt.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.input.lucl6kr1.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.model.n2zmw0v8, fragments:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_1/hmmalign.frag.oo415oy3.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.input.8let4h61.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.model.1pt7yua_, fragments:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_0/hmmalign.frag.bnx5gejh.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.input.lucl6kr1.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.model.1pt7yua_, fragments:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_1/hmmalign.frag.2ck0rwou.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.input.lucl6kr1.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.model.n2zmw0v8, fragments:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_0/hmmalign.frag.01ak4s19.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.input.8let4h61.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.model.n2zmw0v8, fragments:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_2/hmmalign.frag.9c7l2l6f.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.input.8let4h61.fasta
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_3.
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_4.
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_1.
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.model.t7vh54ez, fragments:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_1/hmmalign.frag.kdg06l0m.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.input.w1xm8f8n.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.model.t7vh54ez, fragments:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_2/hmmalign.frag.cojyj0ax.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.input.w1xm8f8n.fasta
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_0/hmmalign.results.39uhoq1i) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.input.lucl6kr1.fasta).
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.model.hok6y546, fragments:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_0/hmmalign.frag.nw2zgyu1.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.input.qz_2ez75.fasta
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_1/hmmalign.results.3ejm3eez) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.input.lucl6kr1.fasta).
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.model.hok6y546, fragments:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_2/hmmalign.frag.k7ywixax.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.input.qz_2ez75.fasta
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/FC_1_0_2/hmmalign.results.gvbghzeo) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_1/A_1_0/hmmbuild.input.lucl6kr1.fasta).
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.model.t7vh54ez, fragments:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_0/hmmalign.frag.xmgvibwy.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.input.w1xm8f8n.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.model.hok6y546, fragments:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_1/hmmalign.frag.74koki61.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.input.qz_2ez75.fasta
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_5.
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_0/hmmalign.results.q8z9jmlh) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.input.8let4h61.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_1/hmmalign.results.ah6vhr2x) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.input.8let4h61.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/FC_5_0_2/hmmalign.results.wgv8bgap) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_5/A_5_0/hmmbuild.input.8let4h61.fasta).
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_7.
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_0/hmmalign.results.ni3lka71) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.input.w1xm8f8n.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_1/hmmalign.results.px7qb8f8) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.input.w1xm8f8n.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/FC_7_0_2/hmmalign.results.v60oj8wt) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_7/A_7_0/hmmbuild.input.w1xm8f8n.fasta).
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.model.p1r0xwcx, fragments:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_1/hmmalign.frag.psfp3owd.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.input.30ndmgra.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.model.p1r0xwcx, fragments:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_2/hmmalign.frag.nfroncpx.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.input.30ndmgra.fasta
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_6.
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_0/hmmalign.results.1hf5uh6i) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.input.qz_2ez75.fasta).
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.model.p1r0xwcx, fragments:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_0/hmmalign.frag.otg488m1.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.input.30ndmgra.fasta
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_1/hmmalign.results.ip1dqrup) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.input.qz_2ez75.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/FC_6_0_2/hmmalign.results.j02kdmu8) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_6/A_6_0/hmmbuild.input.qz_2ez75.fasta).
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_8.
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_0/hmmalign.results.cjtnycq3) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.input.30ndmgra.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_1/hmmalign.results.e_cpb8zv) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.input.30ndmgra.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/FC_8_0_2/hmmalign.results.mk8vc4ea) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_8/A_8_0/hmmbuild.input.30ndmgra.fasta).
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.model.cow4xr2p, fragments:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_1/hmmalign.frag.xab3p6hd.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.input.e19975p0.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.model.cow4xr2p, fragments:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_2/hmmalign.frag._qba3sfn.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.input.e19975p0.fasta
# [20:30:12] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.model.cow4xr2p, fragments:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_0/hmmalign.frag.fdl410el.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.input.e19975p0.fasta
# [20:30:12] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_10.
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_0/hmmalign.results.zyshy_mq) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.input.e19975p0.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_1/hmmalign.results.e6bg9579) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.input.e19975p0.fasta).
# [20:30:12] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/FC_10_0_2/hmmalign.results.jfkmjglw) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_10/A_10_0/hmmbuild.input.e19975p0.fasta).
# [20:30:13] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.model.zs89dovw, fragments:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_2/hmmalign.frag.w6dkpz6r.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.input.h8ftduuq.fasta
# [20:30:13] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.model.zs89dovw, fragments:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_0/hmmalign.frag.e2ag3ujl.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.input.h8ftduuq.fasta
# [20:30:13] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.model.zs89dovw, fragments:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_1/hmmalign.frag.kz3rwnqp.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.input.h8ftduuq.fasta
# [20:30:13] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_9.
# [20:30:13] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_0/hmmalign.results.08jmvi68) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.input.h8ftduuq.fasta).
# [20:30:13] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_1/hmmalign.results.01m8m7kd) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.input.h8ftduuq.fasta).
# [20:30:13] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/FC_9_0_2/hmmalign.results.yqk1yfoo) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_9/A_9_0/hmmbuild.input.h8ftduuq.fasta).
# [20:30:15] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.model.x2_393mh, fragments:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_1/hmmalign.frag.5p91jn5j.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.input.ve7p78rf.fasta
# [20:30:15] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.model.x2_393mh, fragments:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_0/hmmalign.frag.2zj7uu9w.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.input.ve7p78rf.fasta
# [20:30:15] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.model.x2_393mh, fragments:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_2/hmmalign.frag.f2ouag1_.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.input.ve7p78rf.fasta
# [20:30:15] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_12.
# [20:30:15] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_0/hmmalign.results.8ivwko9x) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.input.ve7p78rf.fasta).
# [20:30:15] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_1/hmmalign.results.bde0higl) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.input.ve7p78rf.fasta).
# [20:30:15] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/FC_12_0_2/hmmalign.results.zvsgk2u8) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_12/A_12_0/hmmbuild.input.ve7p78rf.fasta).
# [20:30:15] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.model.fdu3v2if, fragments:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_2/hmmalign.frag.ozrq84o7.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.input.tyqd2jjt.fasta
# [20:30:15] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.model.fdu3v2if, fragments:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_0/hmmalign.frag.84crcvqu.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.input.tyqd2jjt.fasta
# [20:30:15] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.model.fdu3v2if, fragments:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_1/hmmalign.frag.zqe838tz.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.input.tyqd2jjt.fasta
# [20:30:15] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_13.
# [20:30:15] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_0/hmmalign.results.w0n92vnm) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.input.tyqd2jjt.fasta).
# [20:30:15] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_1/hmmalign.results.90omu54a) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.input.tyqd2jjt.fasta).
# [20:30:15] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/FC_13_0_2/hmmalign.results.nue82f2g) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_13/A_13_0/hmmbuild.input.tyqd2jjt.fasta).
# [20:30:16] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.model.xlm77_kl, fragments:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_2/hmmalign.frag.7f3wn3q3.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.input.kdm4ox6b.fasta
# [20:30:16] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.model.xlm77_kl, fragments:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_0/hmmalign.frag.lqbmx0r1.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.input.kdm4ox6b.fasta
# [20:30:16] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.model.xlm77_kl, fragments:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_1/hmmalign.frag.htakmtcd.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.input.kdm4ox6b.fasta
# [20:30:16] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_14.
# [20:30:16] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_0/hmmalign.results.6pgnv6jj) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.input.kdm4ox6b.fasta).
# [20:30:16] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/hmmbuild.model.x9yk1wsh, fragments:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/FC_15_0_0/hmmalign.frag.l0yn3kt9.fasta, trim:False, base_alignment:/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/hmmbuild.input.rvl9n1vi.fasta
# [20:30:16] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_1/hmmalign.results.k8_n7o_f) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.input.kdm4ox6b.fasta).
# [20:30:16] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/FC_14_0_2/hmmalign.results.rn1b1420) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_14/A_14_0/hmmbuild.input.kdm4ox6b.fasta).
# [20:30:16] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_15.
# [20:30:16] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/FC_15_0_0/hmmalign.results.vibzsj4n) into base alignment (/tmp/sepp/output.1m8v3xwz/root/P_15/A_15_0/hmmbuild.input.rvl9n1vi.fasta).
# [20:30:18] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.backbone.qb9tht84.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.tree.gyleor1p.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.extended.2.5__4y2nw.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.extended.2.5__4y2nw.jplace
# [20:30:18] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.backbone.f4z0uoht.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.tree.2g9lx3d2.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.extended.0.jifla6qw.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.extended.0.jifla6qw.jplace
# [20:30:18] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.backbone.eowgkutv.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.tree.wvbvo5e_.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.extended.1._y38tik5.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_1/pplacer.extended.1._y38tik5.jplace
# [20:30:20] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.backbone.qds_2gzo.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.tree.9wbv43p_.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.extended.0.2tel_laq.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.extended.0.2tel_laq.jplace
# [20:30:21] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.backbone.wvyv9xdm.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.tree.g2dfuopz.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.extended.1.0pbpe72g.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.extended.1.0pbpe72g.jplace
# [20:30:21] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.backbone.5jrrujzd.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.tree.ukhvcfty.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.extended.2.em3rkph8.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_5/pplacer.extended.2.em3rkph8.jplace
# [20:30:23] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.backbone.cn34am73.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.tree.yqpmb448.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.extended.1.qf7af78l.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.extended.1.qf7af78l.jplace
# [20:30:23] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.backbone.gx9mhzn_.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.tree.p0wwdrwa.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.extended.0.uzxj5bmu.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_7/pplacer.extended.0.uzxj5bmu.jplace
# ...
# [20:30:42] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.backbone.49yusb4o.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.tree.ia5qdh1k.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.extended.2.ie6a3_9p.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.extended.2.ie6a3_9p.jplace
# [20:30:43] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.backbone.fvadwzxe.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.tree.bdf89s_7.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.extended.1.18hti36f.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_14/pplacer.extended.1.18hti36f.jplace
# [20:30:43] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.backbone.p24d55dw.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.tree.j67d6sfh.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.extended.0.z7sarri2.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.extended.0.z7sarri2.jplace
# [20:30:44] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.backbone.yk72umc7.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.tree.8uldyjhx.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.extended.2.9g_tbv0i.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_12/pplacer.extended.2.9g_tbv0i.jplace
# [20:31:22] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.backbone.e05i0b32.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.tree.h6zcmvh1.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.extended.1.iay3dggd.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.extended.1.iay3dggd.jplace
# [20:31:22] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.backbone.ec0cnsbt.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.tree.6kl9kfu6.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.extended.2.kj85ub7v.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.extended.2.kj85ub7v.jplace
# [20:31:22] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.backbone.4_5mggnu.fasta, tree_file:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.tree.ibjhrv6b.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.extended.0.jowy707c.fasta, output:/tmp/sepp/output.1m8v3xwz/root/P_11/pplacer.extended.0.jowy707c.jplace
# [20:31:28] jobs.py (line 131):     INFO: Finished jsonmerger Job with input: input:pipe output:/tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json
# [20:31:28] algorithm.py (line 196):     INFO: Current execution Finished in 164 seconds
# [20:31:28] algorithm.py (line 198):     INFO: All checkpointed executions Finished in 164 cumulative time
# [20:31:28] algorithm.py (line 207):     INFO: Temp files are left behind at /tmp/sepp/output.1m8v3xwz
#
# gappa examine graft --jplace-path /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json --fully-resolve --out-dir /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out
#
# mv /tmp/tmp5cdhtmw1/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.newick /tmp/tmp5cdhtmw1/picrust2_out/out.tre
#
# Finished placing sequences on output tree: /tmp/tmp5cdhtmw1/picrust2_out/out.tre
# hsp.py --tree /tmp/tmp5cdhtmw1/picrust2_out/out.tre --output /tmp/tmp5cdhtmw1/picrust2_out/marker_predicted_and_nsti.tsv.gz --observed_trait_table /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/16S.txt.gz --hsp_method pic --edge_exponent 0.5 --seed 100 --calculate_NSTI --processes 1 --verbose
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_nsti.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpml__rwvk/known_tips.txt /tmp/tmpml__rwvk/nsti_out.txt
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpqcarubi7/subset_tab_0 pic 0.5 FALSE FALSE /tmp/tmpt1b59duf/predicted_counts.txt /tmp/tmpt1b59duf/predicted_ci.txt 100
#
#
# hsp.py --tree /tmp/tmp5cdhtmw1/picrust2_out/out.tre --output /tmp/tmp5cdhtmw1/picrust2_out/EC_predicted.tsv.gz --observed_trait_table /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/ec.txt.gz --hsp_method pic --edge_exponent 0.5 --seed 100 --processes 6 --verbose
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpw_8wffzw/subset_tab_2 pic 0.5 FALSE FALSE /tmp/tmpds8ag6hz/predicted_counts.txt /tmp/tmpds8ag6hz/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpw_8wffzw/subset_tab_0 pic 0.5 FALSE FALSE /tmp/tmpbrrmna5f/predicted_counts.txt /tmp/tmpbrrmna5f/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpw_8wffzw/subset_tab_1 pic 0.5 FALSE FALSE /tmp/tmpicshwb9v/predicted_counts.txt /tmp/tmpicshwb9v/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpw_8wffzw/subset_tab_3 pic 0.5 FALSE FALSE /tmp/tmp2c8ftlpn/predicted_counts.txt /tmp/tmp2c8ftlpn/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpw_8wffzw/subset_tab_4 pic 0.5 FALSE FALSE /tmp/tmprs9tff_7/predicted_counts.txt /tmp/tmprs9tff_7/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmpw_8wffzw/subset_tab_5 pic 0.5 FALSE FALSE /tmp/tmp2kiei0ra/predicted_counts.txt /tmp/tmp2kiei0ra/predicted_ci.txt 100
#
#
#
#
#
#
#
# hsp.py --tree /tmp/tmp5cdhtmw1/picrust2_out/out.tre --output /tmp/tmp5cdhtmw1/picrust2_out/KO_predicted.tsv.gz --observed_trait_table /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/ko.txt.gz --hsp_method pic --edge_exponent 0.5 --seed 100 --processes 6 --verbose
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_0 pic 0.5 FALSE FALSE /tmp/tmpwzqgpf9j/predicted_counts.txt /tmp/tmpwzqgpf9j/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_1 pic 0.5 FALSE FALSE /tmp/tmplkqzyxt5/predicted_counts.txt /tmp/tmplkqzyxt5/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_2 pic 0.5 FALSE FALSE /tmp/tmp4cq4syil/predicted_counts.txt /tmp/tmp4cq4syil/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_3 pic 0.5 FALSE FALSE /tmp/tmptoa2elsf/predicted_counts.txt /tmp/tmptoa2elsf/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_4 pic 0.5 FALSE FALSE /tmp/tmpsghl1_lo/predicted_counts.txt /tmp/tmpsghl1_lo/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_5 pic 0.5 FALSE FALSE /tmp/tmpn_ow7rtc/predicted_counts.txt /tmp/tmpn_ow7rtc/predicted_ci.txt 100
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_6 pic 0.5 FALSE FALSE /tmp/tmpm87fs1z1/predicted_counts.txt /tmp/tmpm87fs1z1/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_7 pic 0.5 FALSE FALSE /tmp/tmpaapy90x7/predicted_counts.txt /tmp/tmpaapy90x7/predicted_ci.txt 100
#
#
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_8 pic 0.5 FALSE FALSE /tmp/tmpl3k8d5n_/predicted_counts.txt /tmp/tmpl3k8d5n_/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_9 pic 0.5 FALSE FALSE /tmp/tmprxeb1s__/predicted_counts.txt /tmp/tmprxeb1s__/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_10 pic 0.5 FALSE FALSE /tmp/tmpn7nqyv3v/predicted_counts.txt /tmp/tmpn7nqyv3v/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_11 pic 0.5 FALSE FALSE /tmp/tmpso1xmmay/predicted_counts.txt /tmp/tmpso1xmmay/predicted_ci.txt 100
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_12 pic 0.5 FALSE FALSE /tmp/tmp74c7xuh4/predicted_counts.txt /tmp/tmp74c7xuh4/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_13 pic 0.5 FALSE FALSE /tmp/tmpd14bdxz6/predicted_counts.txt /tmp/tmpd14bdxz6/predicted_ci.txt 100
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_14 pic 0.5 FALSE FALSE /tmp/tmpa8x98m1f/predicted_counts.txt /tmp/tmpa8x98m1f/predicted_ci.txt 100
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_15 pic 0.5 FALSE FALSE /tmp/tmps5r4tatw/predicted_counts.txt /tmp/tmps5r4tatw/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_16 pic 0.5 FALSE FALSE /tmp/tmp32bm7ilj/predicted_counts.txt /tmp/tmp32bm7ilj/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_17 pic 0.5 FALSE FALSE /tmp/tmpohc_x2em/predicted_counts.txt /tmp/tmpohc_x2em/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_18 pic 0.5 FALSE FALSE /tmp/tmpmh_qeedf/predicted_counts.txt /tmp/tmpmh_qeedf/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_19 pic 0.5 FALSE FALSE /tmp/tmp4e7d67nk/predicted_counts.txt /tmp/tmp4e7d67nk/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_20 pic 0.5 FALSE FALSE /tmp/tmpcepgp06l/predicted_counts.txt /tmp/tmpcepgp06l/predicted_ci.txt 100
#
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmp5cdhtmw1/picrust2_out/out.tre /tmp/tmp0a77hh5b/subset_tab_21 pic 0.5 FALSE FALSE /tmp/tmp8oi4oaie/predicted_counts.txt /tmp/tmp8oi4oaie/predicted_ci.txt 100
#
#
#
#
#
# Running metagenome pipeline for EC
# metagenome_pipeline.py --input /tmp/tmp5cdhtmw1/intable.biom --function /tmp/tmp5cdhtmw1/picrust2_out/EC_predicted.tsv.gz --min_reads 1 --min_samples 1 --out_dir /tmp/tmp5cdhtmw1/picrust2_out/EC_metagenome_out --max_nsti 2 --marker /tmp/tmp5cdhtmw1/picrust2_out/marker_predicted_and_nsti.tsv.gz
# 1 of 1884 ASVs were above the max NSTI cut-off of 2.0 and were removed from the downstream analyses.
#
# Running metagenome pipeline for KO
# metagenome_pipeline.py --input /tmp/tmp5cdhtmw1/intable.biom --function /tmp/tmp5cdhtmw1/picrust2_out/KO_predicted.tsv.gz --min_reads 1 --min_samples 1 --out_dir /tmp/tmp5cdhtmw1/picrust2_out/KO_metagenome_out --max_nsti 2 --marker /tmp/tmp5cdhtmw1/picrust2_out/marker_predicted_and_nsti.tsv.gz
# Inferring pathways from predicted EC
# 1 of 1884 ASVs were above the max NSTI cut-off of 2.0 and were removed from the downstream analyses.
#
# pathway_pipeline.py --input /tmp/tmp5cdhtmw1/picrust2_out/EC_metagenome_out/pred_metagenome_unstrat.tsv.gz --out_dir /tmp/tmp5cdhtmw1/picrust2_out/pathways_out --map /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/pathway_mapfiles/metacyc_path2rxn_struc_filt_pro.txt --intermediate /tmp/tmp5cdhtmw1/picrust2_out/intermediate/pathways --proc 6 --regroup_map /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/pathway_mapfiles/ec_level4_to_metacyc_rxn.tsv --verbose
# Wrote predicted pathway abundances and coverages to /tmp/tmp5cdhtmw1/picrust2_out/pathways_out

# %% [markdown]
# ### Persist created artifacts
#
# We will define file paths and persist all artifacts. We start with `.qza` files. We will save the visualization files in sequence as `qzv` files. Finally, we save a `biom`-like file as `tsv` with brief descriptions of all functions.

# %%
if need_pipeline:
    # Export artifact folder
    ec_metagenome.export_data(output_dir=ec_path.split('.')[0])
    ko_metagenome.export_data(output_dir=ko_path.split('.')[0])
    pathway_abundance.export_data(output_dir=pathway_path.split('.')[0])
    
    # Save artifacts as .qza files
    ec_metagenome.save(ec_path)
    ko_metagenome.save(ko_path)
    pathway_abundance.save(pathway_path)

# %%
need_viz = replace_files
need_viz |= not (os.path.isfile(ec_viz_path) and os.path.isfile(ko_viz_path) and os.path.isfile(pathway_viz_path))
if need_viz:
    # Create visualization artifacts
    ec_viz = summarize(table=ec_metagenome, sample_metadata=metadata_qa).visualization
    ko_viz = summarize(table=ko_metagenome, sample_metadata=metadata_qa).visualization
    path_viz = summarize(table=pathway_abundance, sample_metadata=metadata_qa).visualization

    # Save visualization artifacts as .qzv files
    ec_viz.save(ec_viz_path)
    ko_viz.save(ko_viz_path)
    path_viz.save(pathway_viz_path)
# Out:
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
tables = (ec_metagenome, ko_metagenome, pathway_abundance)
table_types = ('ec', 'ko', 'path')

for i, t in enumerate(tables):
    print(f'Processing {table_types[i]}')
    results = core_metrics(
        table = t,
        sampling_depth = 1,
        metadata = metadata_qa,
        n_jobs = 6,
    )
    emperor_out = os.path.join(picrust2_folder, f'{table_types[i]}-bray_curtis_emperor.qzv')
    results.bray_curtis_emperor.save(emperor_out)
    emperor_out = os.path.join(picrust2_folder, f'{table_types[i]}-jaccard_emperor.qzv')
    results.jaccard_emperor.save(emperor_out)
# Out:
# Processing ec
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/skbio/util/_warning.py:60: UserWarning: observed_otus is deprecated as of 0.6.0.
#   warn(f"{func.__name__} is deprecated as of {ver}.")
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/q2_diversity_lib/skbio/_methods.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   return _shannon(counts, base=np.e) / np.log(
# Processing ko
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/q2_diversity_lib/skbio/_methods.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   return _shannon(counts, base=np.e) / np.log(
# Processing path
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/q2_diversity_lib/skbio/_methods.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   return _shannon(counts, base=np.e) / np.log(

# %%
need_biom = replace_files
need_biom |= not (os.path.isfile(ec_fpath) and os.path.isfile(ko_fpath) and os.path.isfile(pathway_fpath))
if need_biom:
    # Convert artifact to dataframe - transposed
    df_pathway = pathway_abundance.view(pd.DataFrame).T
    df_ec = ec_metagenome.view(pd.DataFrame).T
    df_ko = ko_metagenome.view(pd.DataFrame).T

    # Write dataframe to a tsv file
    df_pathway.to_csv(pathway_fpath, sep='\t', index=True)
    df_ec.to_csv(ec_fpath, sep='\t', index=True)
    df_ko.to_csv(ko_fpath, sep='\t', index=True)
    
    # Put a new column with descriptions of each function's ID
    # !add_descriptions.py -i {ec_fpath} -m EC -o {ec_desc_fpath}
    # !add_descriptions.py -i {ko_fpath} -m KO -o {ko_desc_fpath}
    # !add_descriptions.py -i {pathway_fpath} -m METACYC -o {pathway_desc_fpath}

# %% [markdown]
# ### Aggregate by sum groups counts
#
# We create new columns with the aggregation of the counts for all groups.

# %%
# Create a new DataFrame with Metadata info
metadata_df = metadata_qa.to_dataframe()
# Select all groups
group_ids = metadata_df[class_col].unique()

# %%
# Iterate over all PICRUST2 files
for f in (ec_desc_fpath, ko_desc_fpath, pathway_desc_fpath):
    # Create new DataFrame to store new data
    df = pd.read_csv(f, sep='\t')
    new_df = pd.DataFrame()
    # Iterate over all groups
    for g in group_ids:
        # Select all IDs from current group
        idx = metadata_df[metadata_df[class_col]==g].index
        # Sum all values from samples of the current group
        tmp = df.loc[:, idx].sum(axis=1)
        # Create a new column with the sum
        new_df[g] = tmp
    # Sum the values of all groups
    new_df['Total'] = new_df.sum(axis=1)
    # Join new columns into the end of the original DataFrame
    new_df = pd.concat([df, new_df])
    # Write joined DataFrame to file - overwrite
    new_df.to_csv(f, index=False, sep='\t')
