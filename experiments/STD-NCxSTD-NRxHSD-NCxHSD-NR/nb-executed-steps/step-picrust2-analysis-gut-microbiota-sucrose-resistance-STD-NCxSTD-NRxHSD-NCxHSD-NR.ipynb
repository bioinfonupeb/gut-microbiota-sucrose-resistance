# %% [markdown]
# ### STEP : PICRUST2 Analysis
#
#
#
# #### Example
#
# - [PICRUST2 tutorial](https://github.com/picrust/picrust2/wiki/q2-picrust2-Tutorial)
# - [Limitations](https://github.com/picrust/picrust2/wiki/Key-Limitations)
#
#
# #### Methods
# - [composition](https://docs.qiime2.org/2022.8/plugins/available/composition/)

# %% [markdown]
# ## Setup and settings

# %%
# Importing packages
import os
import biom
import pandas as pd
from qiime2 import Artifact
from qiime2 import Visualization
from qiime2 import Metadata

from qiime2.plugins.feature_table.visualizers import summarize
from qiime2.plugins.diversity.pipelines import core_metrics

from picrust2.pipeline import full_pipeline
from picrust2.default import (default_ref_dir, default_tables, default_regroup_map, default_pathway_map)
from qiime2.plugins import picrust2
from qiime2.plugins.feature_table.methods import filter_samples
from qiime2.plugins.feature_table.methods import filter_seqs

# %matplotlib inline

# %% [markdown]
# ### Receiving the parameters
#
# The following cell can receive parameters using the [papermill](https://papermill.readthedocs.io/en/latest/) tool.

# %%
metadata_file = '/home/lauro/nupeb/rede-micro/redemicro-miliane-nutri/data/raw/metadata/miliane-metadata-CxAC.tsv'
base_dir = os.path.join('/', 'home', 'lauro', 'nupeb', 'rede-micro', 'redemicro-miliane-nutri')
experiment_name = 'miliane-CxAC-trim'
class_col = 'group-id'
replace_files = False

# %%
# Parameters
base_dir = "/mnt/nupeb/rede-micro/redemicro-ana-flavia-nutri"
class_col = "group-id"
classifier_file = "/mnt/nupeb/rede-micro/datasets/16S_classifiers_qiime2/silva138.1_AB_V3-V4_classifier.qza"
experiment_name = "ana-flavia-STD-NCxSTD-NRxHSD-NCxHSD-NR"
manifest_file = "/mnt/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/selected_groups/manifest_STD-NCxSTD-NRxHSD-NCxHSD-NR.csv"
metadata_file = "/mnt/nupeb/rede-micro/redemicro-ana-flavia-nutri/data/raw/selected_groups/metadata_STD-NCxSTD-NRxHSD-NCxHSD-NR.tsv"
overlap = 12
phred = 20
replace_files = False
threads = 6
top_n = 20
trim = {"forward_primer": "CCTACGGGRSGCAGCAG", "overlap": 8, "reverse_primer": "GGACTACHVGGGTWTCTAAT"}
trunc_f = 0
trunc_r = 0

# %%
experiment_folder = os.path.abspath(os.path.join(base_dir, 'experiments', experiment_name))
img_folder = os.path.abspath(os.path.join(experiment_folder, 'imgs'))

# %% [markdown]
# ### Defining names, paths and flags

# %%
# QIIME2 Artifacts folder
qiime_folder = os.path.join(experiment_folder, 'qiime-artifacts')

# Input - DADA2 Artifacts
dada2_tabs_path = os.path.join(qiime_folder, 'dada2-tabs.qza')
dada2_reqs_path = os.path.join(qiime_folder, 'dada2-reps.qza')

# PICRUST@ folder
picrust2_folder = os.path.abspath(os.path.join(experiment_folder, 'picrust2'))

# Create path if it not exist
if not os.path.isdir(picrust2_folder):
    os.makedirs(picrust2_folder)
    print(f'New picrust2-artifacts folder path created: {picrust2_folder}')

# %%
# Define paths for metagenome function artifacts
ec_path = os.path.join(picrust2_folder, 'ec-pred-metagen.qza')
ko_path = os.path.join(picrust2_folder, 'ko-pred-metagen.qza')
pathway_path = os.path.join(picrust2_folder, 'pathway-abundance.qza')

# Define paths for metagenome function visualization artifacts
ec_viz_path = ec_path[:-1]+'v'
ko_viz_path = ko_path[:-1]+'v'
pathway_viz_path = pathway_path[:-1]+'v'

# Define paths for biom -> tsv files (function X sample)
pathway_fpath = os.path.join(picrust2_folder, 'pathway.tsv')
ec_fpath = os.path.join(picrust2_folder, 'ec.tsv')
ko_fpath = os.path.join(picrust2_folder, 'ko.tsv')

# Define paths for biom -> tsv files (function X sample) - with descriptions
pathway_desc_fpath = os.path.join(picrust2_folder, 'pathway-desc.tsv')
ec_desc_fpath = os.path.join(picrust2_folder, 'ec-desc.tsv')
ko_desc_fpath = os.path.join(picrust2_folder, 'ko-desc.tsv')

# %% [markdown]
# ## Step execution
#
# ### Load input files
#
# This Step import the QIIME2 `FeatureTable[Frequency]` Artifact and the `Metadata` file.

# %%
#Load Metadata
metadata_qa = Metadata.load(metadata_file)

#Load FeatureTable[Frequency]
tabs = Artifact.load(dada2_tabs_path)

#Load FeatureTable[Sequence]
seqs = Artifact.load(dada2_reqs_path)

# %%
# Filter FeatureTable[Frequency | RelativeFrequency | PresenceAbsence | Composition] based on Metadata sample ID values
tabs = filter_samples(
    table=tabs,
    metadata=metadata_qa,
).filtered_table
# Filter SampleData[SequencesWithQuality | PairedEndSequencesWithQuality | JoinedSequencesWithQuality] based on Metadata sample ID values; returns FeatureData[Sequence | AlignedSequence]
seqs = filter_seqs(
    data=seqs,
    table=tabs,
).filtered_data

# %% [markdown]
# ### Execute full pipelie
#
# The entire PICRUSt2 pipeline will be run using a single method, called `picrust2.methods.full_pipeline`. This method will run each of the 4 key steps:
#
# 1. sequence placement
# 2. hidden-state prediction of genomes
# 3. metagenome prediction
# 4. pathway-level predictions.
#
# More information on [Documentation](https://github.com/picrust/picrust2/wiki/Full-pipeline-script).

# %%
need_pipeline = replace_files
need_pipeline |= not (os.path.isfile(ec_path) and os.path.isfile(ko_path) and os.path.isfile(pathway_path))
if need_pipeline:
    results = picrust2.methods.full_pipeline(
        table=tabs, 
        seq=seqs, 
        threads=6, 
        placement_tool='sepp',
        hsp_method='pic', 
        max_nsti=2,
        highly_verbose=True
    )
    ec_metagenome = results.ec_metagenome
    ko_metagenome = results.ko_metagenome
    pathway_abundance = results.pathway_abundance
else:
    ec_metagenome = Artifact.load(ec_path)
    ko_metagenome = Artifact.load(ko_path)
    pathway_abundance = Artifact.load(pathway_path)
# Out:
# 1633 of 1633 sequence ids overlap between input table and FASTA.
#
# Placing sequences onto reference tree
# place_seqs.py --study_fasta /tmp/tmpe5gvh6vv/seqs.fna --ref_dir /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref --out_tree /tmp/tmpe5gvh6vv/picrust2_out/out.tre --processes 6 --intermediate /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs --min_align 0.8 --chunk_size 5000 --placement_tool sepp --verbose
#                                               ....      ....
#                                              '' '||.   .||'
#                                                   ||  ||
#                                                   '|.|'
#      ...'   ....   ... ...  ... ...   ....        .|'|.
#     |  ||  '' .||   ||'  ||  ||'  || '' .||      .|'  ||
#      |''   .|' ||   ||    |  ||    | .|' ||     .|'|.  ||
#     '....  '|..'|'. ||...'   ||...'  '|..'|.    '||'    ||:.
#     '....'          ||       ||
#                    ''''     ''''   v0.8.5 (c) 2017-2024
#                                    by Lucas Czech and Pierre Barbera
#
# Invocation:                        gappa examine graft --jplace-path /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json --fully-resolve --out-dir /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out
# Command:                           gappa examine graft
#
# Input:
#   --jplace-path                    /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json
#
# Settings:
#   --fully-resolve                  true
#   --name-prefix
#
# Output:
#   --out-dir                        /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out
#   --file-prefix
#   --file-suffix
#
# Newick Tree Output:
#   --newick-tree-quote-invalid-chars
#                                    false
#
# Global Options:
#   --allow-file-overwriting         false
#   --verbose                        false
#   --threads                        10
#   --log-file
#
# Run the following command to get the references that need to be cited:
# `gappa tools citation Czech2020-genesis-and-gappa`
#
# Started 2024-11-04 20:20:32
#
# Found 1 jplace file
#
# Finished 2024-11-04 20:20:32
# hmmalign --trim --dna --mapali /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.fna --informat FASTA -o /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/query_align.stockholm /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.hmm /tmp/tmpe5gvh6vv/seqs.fna
#
# Warning - 1 input sequences aligned poorly to reference sequences (--min_align option specified a minimum proportion of 0.8 aligning to reference sequences). These input sequences will not be placed and will be excluded from downstream steps.
#
# This is the set of poorly aligned input sequences to be excluded: 6fed430d2c42021ed5fa531745f38fba
#
# Raw input sequences ranged in length from 253 to 430
#
# run_sepp.py --tree /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.tre --raxml /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info --cpu 6 --molecule dna --outdir /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out -seed 297834 --alignment /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.fna --fragment /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/study_seqs_filtered.fasta
# [20:18:04] config.py (line 370):     INFO: Seed number: 297834
# [20:18:04] algorithm.py (line 267):     INFO: Reading input alignment: <_io.TextIOWrapper name='/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.fna' mode='r' encoding='UTF-8'>
# [20:18:05] algorithm.py (line 274):     INFO: Reading input tree: <_io.TextIOWrapper name='/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.tre' mode='r' encoding='UTF-8'>
# [20:18:05] algorithm.py (line 247):     INFO: Decomposition Sizes are set to alignment: 2000 placement: 2000
# [20:18:07] exhaustive.py (line 351):     INFO: Breaking into 16 placement subsets.
# [20:18:08] exhaustive.py (line 398):     INFO: Breaking into 16 alignment subsets.
# [20:18:08] filemgr.py (line 129):     INFO: Root temp directory built: /tmp/sepp/output.unoxcepj
# [20:18:08] exhaustive.py (line 413):     INFO: Breaking each alignment subset into 3 fragment chunks.
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_4/A_4_0/hmmbuild.input.rrim2_ei.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_0/A_0_0/hmmbuild.input.e0ijrgyx.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.input.nk9at1kw.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.input.xg2yqbyj.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_3/A_3_0/hmmbuild.input.aynye2ve.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_2/A_2_0/hmmbuild.input.3tfy57tc.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.input.d10frjj6.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.input.3isyvnrt.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.input.jrvltzm6.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.input.x316k6j4.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.input.ewpndmx6.fasta
# [20:18:10] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.input.8211xiit.fasta
# [20:18:11] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.input.4_l0lo9s.fasta
# [20:18:11] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.input.wgpn6rbo.fasta
# [20:18:11] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.input.h53_5qjx.fasta
# [20:18:11] jobs.py (line 131):     INFO: Finished hmmbuild Job with input: /tmp/sepp/output.unoxcepj/root/P_15/A_15_0/hmmbuild.input.pgo2wwvi.fasta
# [20:18:19] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_4/A_4_0/hmmbuild.model.e9enuf0y, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_4/A_4_0/FC_4_0_0/hmmsearch.results.x9py8b31
# [20:18:19] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_4/A_4_0/hmmbuild.model.e9enuf0y, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_4/A_4_0/FC_4_0_1/hmmsearch.results.e9fa9uee
# [20:18:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_4/A_4_0/hmmbuild.model.e9enuf0y, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_4/A_4_0/FC_4_0_2/hmmsearch.results.czp9ulws
# [20:18:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_0/A_0_0/hmmbuild.model.pxk1laip, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_0/A_0_0/FC_0_0_0/hmmsearch.results.99whqavb
# [20:18:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_0/A_0_0/hmmbuild.model.pxk1laip, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_0/A_0_0/FC_0_0_2/hmmsearch.results.0ux8adhh
# [20:18:20] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_0/A_0_0/hmmbuild.model.pxk1laip, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_0/A_0_0/FC_0_0_1/hmmsearch.results.xfqbc__d
# [20:18:28] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.model.ziwu34pe, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_0/hmmsearch.results.pazm4udk
# [20:18:28] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.model.ziwu34pe, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_1/hmmsearch.results._op7m6id
# [20:18:28] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.model.ziwu34pe, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_2/hmmsearch.results.ribencnt
# [20:18:28] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.model.t8a0qbz1, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_2/hmmsearch.results.founlnw4
# [20:18:28] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.model.t8a0qbz1, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_0/hmmsearch.results.5aohxtuk
# [20:18:28] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.model.t8a0qbz1, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_1/hmmsearch.results.ll5n_g3z
# [20:18:37] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_3/A_3_0/hmmbuild.model._4a00c9p, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_3/A_3_0/FC_3_0_0/hmmsearch.results.p53zkrz5
# [20:18:37] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_3/A_3_0/hmmbuild.model._4a00c9p, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_3/A_3_0/FC_3_0_1/hmmsearch.results.o_nqw467
# [20:18:37] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_3/A_3_0/hmmbuild.model._4a00c9p, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_3/A_3_0/FC_3_0_2/hmmsearch.results.a0i7ch5n
# [20:18:37] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_2/A_2_0/hmmbuild.model.x23rqfx5, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_2/A_2_0/FC_2_0_2/hmmsearch.results.4rknqqlg
# [20:18:37] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_2/A_2_0/hmmbuild.model.x23rqfx5, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_2/A_2_0/FC_2_0_1/hmmsearch.results.4x34sh_4
# [20:18:37] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_2/A_2_0/hmmbuild.model.x23rqfx5, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_2/A_2_0/FC_2_0_0/hmmsearch.results.wqtakth2
# [20:18:46] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.model.cfl9k0vq, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_0/hmmsearch.results.urqivblj
# [20:18:46] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.model.cfl9k0vq, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_1/hmmsearch.results.bopluw6b
# [20:18:46] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.model.cfl9k0vq, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_2/hmmsearch.results.96q1h4a1
# [20:18:46] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.model.5pgdhzqk, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_1/hmmsearch.results.qysf5qrr
# [20:18:46] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.model.5pgdhzqk, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_2/hmmsearch.results.ccx770bm
# [20:18:46] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.model.5pgdhzqk, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_0/hmmsearch.results.74iz9txm
# [20:18:55] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.model.9mo8it80, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_0/hmmsearch.results.yoocc1sz
# [20:18:55] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.model.9mo8it80, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_1/hmmsearch.results.ll4aw9r7
# [20:18:55] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.model.9mo8it80, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_2/hmmsearch.results._cr5cx7i
# [20:18:55] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.model.p6w1r_ry, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/FC_11_0_1/hmmsearch.results.aydb8fro
# [20:18:55] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.model.p6w1r_ry, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/FC_11_0_0/hmmsearch.results.pchct7_3
# [20:18:55] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.model.p6w1r_ry, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/FC_11_0_2/hmmsearch.results.1l7u_fg7
# [20:19:04] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.model.f95r218x, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_0/hmmsearch.results.xzp9xfru
# [20:19:04] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.model.f95r218x, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_1/hmmsearch.results.ijg7nudd
# [20:19:04] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.model.f95r218x, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_2/hmmsearch.results.20iwn00p
# [20:19:04] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.model.o8znmhdw, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_2/hmmsearch.results.cdyhkgji
# [20:19:04] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.model.o8znmhdw, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_0/hmmsearch.results.emsgct7n
# [20:19:04] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.model.o8znmhdw, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_1/hmmsearch.results.e7jytzs0
# [20:19:13] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.model.j623_ijw, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_0/hmmsearch.results.qsdxskdr
# [20:19:13] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.model.j623_ijw, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_1/hmmsearch.results.sl45oi3o
# [20:19:13] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.model.j623_ijw, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_2/hmmsearch.results.ewca6q9l
# [20:19:13] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.model.246xdwbt, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_0/hmmsearch.results._38ui29n
# [20:19:13] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.model.246xdwbt, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_2/hmmsearch.results.gi9uwssn
# [20:19:13] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.model.246xdwbt, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_1/hmmsearch.results.ldo3xq3l
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.model.mbe0fa9n, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_0/hmmsearch.results.1eyvq342
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.model.mbe0fa9n, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_1/hmmsearch.results.al_0wfum
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.model.mbe0fa9n, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_2/hmmsearch.results.j4i1dm6f
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/hmmbuild.model.vrm0snbg, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_2ij97ccgf.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/FC_15_0_2/hmmsearch.results.bn_l52v7
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/hmmbuild.model.vrm0snbg, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_0e7_13lk9.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/FC_15_0_0/hmmsearch.results.z3wufu8q
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmsearch Job with input: model:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/hmmbuild.model.vrm0snbg, fragments:/tmp/sepp/output.unoxcepj/fragment_chunks/fragment_chunk_17ik023mr.fasta, elim:99999999, filter:False, output:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/FC_15_0_1/hmmsearch.results.hr92j3tb
# [20:19:22] exhaustive.py (line 81):  WARNING: Fragments [] are not scored against any subset
# [20:19:22] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_0.
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.model.ziwu34pe, fragments:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_0/hmmalign.frag.e2uje8h4.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.input.nk9at1kw.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.model.ziwu34pe, fragments:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_2/hmmalign.frag.qjm55kw_.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.input.nk9at1kw.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.model.t8a0qbz1, fragments:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_2/hmmalign.frag.fh8ppf6f.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.input.xg2yqbyj.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.model.ziwu34pe, fragments:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_1/hmmalign.frag.f4zvcpc8.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.input.nk9at1kw.fasta
# [20:19:22] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_2.
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.model.t8a0qbz1, fragments:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_1/hmmalign.frag.m8j4xbhc.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.input.xg2yqbyj.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.model.t8a0qbz1, fragments:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_0/hmmalign.frag.8uoe15vd.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.input.xg2yqbyj.fasta
# [20:19:22] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_3.
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.model.5pgdhzqk, fragments:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_2/hmmalign.frag.27pfp0vx.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.input.3isyvnrt.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.model.9mo8it80, fragments:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_0/hmmalign.frag.yaf32c6r.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.input.jrvltzm6.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.model.5pgdhzqk, fragments:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_0/hmmalign.frag.fmo7m78k.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.input.3isyvnrt.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.model.9mo8it80, fragments:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_2/hmmalign.frag.zxd0k0xx.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.input.jrvltzm6.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.model.5pgdhzqk, fragments:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_1/hmmalign.frag.qjptfqfx.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.input.3isyvnrt.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.model.9mo8it80, fragments:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_1/hmmalign.frag.4wrboz76.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.input.jrvltzm6.fasta
# [20:19:22] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_4.
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.model.cfl9k0vq, fragments:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_0/hmmalign.frag.qx_9vg0h.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.input.d10frjj6.fasta
# [20:19:22] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_1.
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.model.cfl9k0vq, fragments:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_1/hmmalign.frag.twyc6yz5.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.input.d10frjj6.fasta
# [20:19:22] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.model.cfl9k0vq, fragments:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_2/hmmalign.frag.k3c3dyo9.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.input.d10frjj6.fasta
# [20:19:22] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_0/hmmalign.results.9_rtyrpu) into base alignment (/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.input.nk9at1kw.fasta).
# [20:19:22] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_1/hmmalign.results.e208wgu0) into base alignment (/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.input.nk9at1kw.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/FC_1_0_2/hmmalign.results.9qmsfktq) into base alignment (/tmp/sepp/output.unoxcepj/root/P_1/A_1_0/hmmbuild.input.nk9at1kw.fasta).
# [20:19:23] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_5.
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_0/hmmalign.results.qyrvw_4f) into base alignment (/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.input.xg2yqbyj.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_1/hmmalign.results.r93bvfvq) into base alignment (/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.input.xg2yqbyj.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/FC_5_0_2/hmmalign.results.zz4y8g83) into base alignment (/tmp/sepp/output.unoxcepj/root/P_5/A_5_0/hmmbuild.input.xg2yqbyj.fasta).
# [20:19:23] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.model.f95r218x, fragments:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_1/hmmalign.frag._j1v7wce.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.input.ewpndmx6.fasta
# [20:19:23] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.model.f95r218x, fragments:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_2/hmmalign.frag.ghn0mliz.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.input.ewpndmx6.fasta
# [20:19:23] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_6.
# [20:19:23] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.model.f95r218x, fragments:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_0/hmmalign.frag.o72vrzik.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.input.ewpndmx6.fasta
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_0/hmmalign.results.f7e20v0h) into base alignment (/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.input.3isyvnrt.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_1/hmmalign.results.yoafip4g) into base alignment (/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.input.3isyvnrt.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/FC_6_0_2/hmmalign.results.y4voiz_6) into base alignment (/tmp/sepp/output.unoxcepj/root/P_6/A_6_0/hmmbuild.input.3isyvnrt.fasta).
# [20:19:23] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.model.o8znmhdw, fragments:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_1/hmmalign.frag.9ugkg2ow.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.input.8211xiit.fasta
# [20:19:23] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.model.o8znmhdw, fragments:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_2/hmmalign.frag.yy5y_3k5.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.input.8211xiit.fasta
# [20:19:23] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.model.o8znmhdw, fragments:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_0/hmmalign.frag.5cgehd49.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.input.8211xiit.fasta
# [20:19:23] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_7.
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_0/hmmalign.results.7jxx1xin) into base alignment (/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.input.jrvltzm6.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_1/hmmalign.results.sac12xlc) into base alignment (/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.input.jrvltzm6.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/FC_7_0_2/hmmalign.results.cs2r3zgz) into base alignment (/tmp/sepp/output.unoxcepj/root/P_7/A_7_0/hmmbuild.input.jrvltzm6.fasta).
# [20:19:23] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_8.
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_0/hmmalign.results.mjgvqff1) into base alignment (/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.input.d10frjj6.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_1/hmmalign.results.1gn3tql7) into base alignment (/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.input.d10frjj6.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/FC_8_0_2/hmmalign.results.wgyhm1vi) into base alignment (/tmp/sepp/output.unoxcepj/root/P_8/A_8_0/hmmbuild.input.d10frjj6.fasta).
# [20:19:23] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_10.
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_0/hmmalign.results.d407dcr4) into base alignment (/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.input.ewpndmx6.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_1/hmmalign.results.mh7yw13m) into base alignment (/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.input.ewpndmx6.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/FC_10_0_2/hmmalign.results.q12kpj0t) into base alignment (/tmp/sepp/output.unoxcepj/root/P_10/A_10_0/hmmbuild.input.ewpndmx6.fasta).
# [20:19:23] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_9.
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_0/hmmalign.results.dq9lkz17) into base alignment (/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.input.8211xiit.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_1/hmmalign.results.rg8agduz) into base alignment (/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.input.8211xiit.fasta).
# [20:19:23] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/FC_9_0_2/hmmalign.results.mwak1fvi) into base alignment (/tmp/sepp/output.unoxcepj/root/P_9/A_9_0/hmmbuild.input.8211xiit.fasta).
# [20:19:25] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.model.j623_ijw, fragments:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_0/hmmalign.frag.j4fshh_p.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.input.4_l0lo9s.fasta
# [20:19:25] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.model.j623_ijw, fragments:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_1/hmmalign.frag.fyzeikpm.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.input.4_l0lo9s.fasta
# [20:19:25] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.model.j623_ijw, fragments:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_2/hmmalign.frag.vzs8jrzl.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.input.4_l0lo9s.fasta
# [20:19:25] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_12.
# [20:19:25] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_0/hmmalign.results.1lozqvyy) into base alignment (/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.input.4_l0lo9s.fasta).
# [20:19:25] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_1/hmmalign.results.8nijgt_8) into base alignment (/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.input.4_l0lo9s.fasta).
# [20:19:25] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/FC_12_0_2/hmmalign.results.q_6sfxvt) into base alignment (/tmp/sepp/output.unoxcepj/root/P_12/A_12_0/hmmbuild.input.4_l0lo9s.fasta).
# [20:19:26] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.model.246xdwbt, fragments:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_0/hmmalign.frag.rw0i2cq0.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.input.wgpn6rbo.fasta
# [20:19:26] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.model.246xdwbt, fragments:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_2/hmmalign.frag.z276g8ra.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.input.wgpn6rbo.fasta
# [20:19:26] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.model.246xdwbt, fragments:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_1/hmmalign.frag.vfu_c_gr.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.input.wgpn6rbo.fasta
# [20:19:26] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_13.
# [20:19:26] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_0/hmmalign.results.9fj44ns6) into base alignment (/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.input.wgpn6rbo.fasta).
# [20:19:26] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_1/hmmalign.results.ay94fpoc) into base alignment (/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.input.wgpn6rbo.fasta).
# [20:19:26] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/FC_13_0_2/hmmalign.results.eo1s5usl) into base alignment (/tmp/sepp/output.unoxcepj/root/P_13/A_13_0/hmmbuild.input.wgpn6rbo.fasta).
# [20:19:26] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.model.mbe0fa9n, fragments:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_2/hmmalign.frag.avn37qc1.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.input.h53_5qjx.fasta
# [20:19:26] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.model.mbe0fa9n, fragments:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_1/hmmalign.frag.ml3obmbp.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.input.h53_5qjx.fasta
# [20:19:26] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.model.mbe0fa9n, fragments:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_0/hmmalign.frag.0wjtmsm7.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.input.h53_5qjx.fasta
# [20:19:26] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_14.
# [20:19:26] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_0/hmmalign.results.mc4qup1t) into base alignment (/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.input.h53_5qjx.fasta).
# [20:19:26] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_1/hmmalign.results.6je8gztv) into base alignment (/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.input.h53_5qjx.fasta).
# [20:19:26] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/hmmbuild.model.vrm0snbg, fragments:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/FC_15_0_0/hmmalign.frag.nlncjw3s.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/hmmbuild.input.pgo2wwvi.fasta
# [20:19:26] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/FC_14_0_2/hmmalign.results.axxnt6hy) into base alignment (/tmp/sepp/output.unoxcepj/root/P_14/A_14_0/hmmbuild.input.h53_5qjx.fasta).
# [20:19:26] exhaustive.py (line 152):     INFO: Merging sub-alignments for placement problem : P_15.
# [20:19:26] alignment.py (line 566):     INFO: Merging extension sto file (/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/FC_15_0_0/hmmalign.results.q5zwxu54) into base alignment (/tmp/sepp/output.unoxcepj/root/P_15/A_15_0/hmmbuild.input.pgo2wwvi.fasta).
# [20:19:28] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.backbone.15qse5mt.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.tree.ha53amb4.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.extended.0.dnlpedgb.fasta, output:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.extended.0.dnlpedgb.jplace
# [20:19:28] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.backbone.owhcag25.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.tree.fcbitc0h.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.extended.2.a2ewj_8y.fasta, output:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.extended.2.a2ewj_8y.jplace
# [20:19:28] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.backbone.1grdfs0x.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.tree.yyhlvtsq.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.extended.1.hkf5x3uv.fasta, output:/tmp/sepp/output.unoxcepj/root/P_1/pplacer.extended.1.hkf5x3uv.jplace
# [20:19:31] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.backbone.b07yzi7h.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.tree.gkqktmtq.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.extended.2.r6dr0_qh.fasta, output:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.extended.2.r6dr0_qh.jplace
# [20:19:31] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.backbone.lenfurr7.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.tree.nztrniru.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.extended.0.j31lxhsj.fasta, output:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.extended.0.j31lxhsj.jplace
# [20:19:31] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.backbone.1oz4wh4y.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.tree.0h52fetc.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.extended.1.a2p7kb12.fasta, output:/tmp/sepp/output.unoxcepj/root/P_5/pplacer.extended.1.a2p7kb12.jplace
# [20:19:34] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_6/pplacer.backbone.7_tu0xpd.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_6/pplacer.tree.f9s7r169.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_6/pplacer.extended.2.tq1dn43l.fasta, output:/tmp/sepp/output.unoxcepj/root/P_6/pplacer.extended.2.tq1dn43l.jplace
# [20:19:34] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.model.p6w1r_ry, fragments:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/FC_11_0_0/hmmalign.frag.79kqk_lu.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.input.x316k6j4.fasta
# [20:19:34] jobs.py (line 131):     INFO: Finished hmmalign Job with input: model:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.model.p6w1r_ry, fragments:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/FC_11_0_1/hmmalign.frag.7ptvkxo5.fasta, trim:False, base_alignment:/tmp/sepp/output.unoxcepj/root/P_11/A_11_0/hmmbuild.input.x316k6j4.fasta
# ...
# [20:19:50] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_12/pplacer.backbone.mcd9ashg.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_12/pplacer.tree.zkwjkdqd.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_12/pplacer.extended.0.a6bps4y9.fasta, output:/tmp/sepp/output.unoxcepj/root/P_12/pplacer.extended.0.a6bps4y9.jplace
# [20:19:50] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.backbone.yq8ytlzv.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.tree.pcqenrx0.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.extended.2.hsl_e895.fasta, output:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.extended.2.hsl_e895.jplace
# [20:19:51] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_15/pplacer.backbone.hj99s1ec.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_15/pplacer.tree.djr6l2w5.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_15/pplacer.extended.0.som0_put.fasta, output:/tmp/sepp/output.unoxcepj/root/P_15/pplacer.extended.0.som0_put.jplace
# [20:19:52] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.backbone.bw3w5jle.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.tree.zyzyng7f.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.extended.1.355yuf_c.fasta, output:/tmp/sepp/output.unoxcepj/root/P_14/pplacer.extended.1.355yuf_c.jplace
# [20:20:25] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.backbone.rz7ij3zb.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.tree.5cs6tncm.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.extended.0.8w5vpo5d.fasta, output:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.extended.0.8w5vpo5d.jplace
# [20:20:26] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.backbone.dixxjbpl.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.tree.0c3r29pv.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.extended.1.7d6vukil.fasta, output:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.extended.1.7d6vukil.jplace
# [20:20:26] jobs.py (line 131):     INFO: Finished pplacer Job with input: backbone_alignment_file:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.backbone.ni8fkbzf.fasta, tree_file:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.tree.8i1vp9w5.tre, info_file:/opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/pro_ref/pro_ref.raxml_info, extended alignment:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.extended.2.kzy5f5vv.fasta, output:/tmp/sepp/output.unoxcepj/root/P_11/pplacer.extended.2.kzy5f5vv.jplace
# [20:20:31] jobs.py (line 131):     INFO: Finished jsonmerger Job with input: input:pipe output:/tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json
# [20:20:31] algorithm.py (line 196):     INFO: Current execution Finished in 147 seconds
# [20:20:31] algorithm.py (line 198):     INFO: All checkpointed executions Finished in 147 cumulative time
# [20:20:31] algorithm.py (line 207):     INFO: Temp files are left behind at /tmp/sepp/output.unoxcepj
#
# gappa examine graft --jplace-path /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.json --fully-resolve --out-dir /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out
#
# mv /tmp/tmpe5gvh6vv/picrust2_out/intermediate/place_seqs/sepp_out/output_placement.newick /tmp/tmpe5gvh6vv/picrust2_out/out.tre
#
# Finished placing sequences on output tree: /tmp/tmpe5gvh6vv/picrust2_out/out.tre
# hsp.py --tree /tmp/tmpe5gvh6vv/picrust2_out/out.tre --output /tmp/tmpe5gvh6vv/picrust2_out/marker_predicted_and_nsti.tsv.gz --observed_trait_table /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/16S.txt.gz --hsp_method pic --edge_exponent 0.5 --seed 100 --calculate_NSTI --processes 1 --verbose
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_nsti.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmph8g9cb9l/known_tips.txt /tmp/tmph8g9cb9l/nsti_out.txt
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmp45ubzuhl/subset_tab_0 pic 0.5 FALSE FALSE /tmp/tmpkf_ix375/predicted_counts.txt /tmp/tmpkf_ix375/predicted_ci.txt 100
#
#
# hsp.py --tree /tmp/tmpe5gvh6vv/picrust2_out/out.tre --output /tmp/tmpe5gvh6vv/picrust2_out/EC_predicted.tsv.gz --observed_trait_table /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/ec.txt.gz --hsp_method pic --edge_exponent 0.5 --seed 100 --processes 6 --verbose
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmp74sfvv0w/subset_tab_1 pic 0.5 FALSE FALSE /tmp/tmp36way2dh/predicted_counts.txt /tmp/tmp36way2dh/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmp74sfvv0w/subset_tab_4 pic 0.5 FALSE FALSE /tmp/tmp6ar7oay1/predicted_counts.txt /tmp/tmp6ar7oay1/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmp74sfvv0w/subset_tab_2 pic 0.5 FALSE FALSE /tmp/tmpvmboot94/predicted_counts.txt /tmp/tmpvmboot94/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmp74sfvv0w/subset_tab_5 pic 0.5 FALSE FALSE /tmp/tmpyf6syczy/predicted_counts.txt /tmp/tmpyf6syczy/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmp74sfvv0w/subset_tab_0 pic 0.5 FALSE FALSE /tmp/tmp3nbyuq1m/predicted_counts.txt /tmp/tmp3nbyuq1m/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmp74sfvv0w/subset_tab_3 pic 0.5 FALSE FALSE /tmp/tmpuvq293zr/predicted_counts.txt /tmp/tmpuvq293zr/predicted_ci.txt 100
#
#
#
#
#
#
#
# hsp.py --tree /tmp/tmpe5gvh6vv/picrust2_out/out.tre --output /tmp/tmpe5gvh6vv/picrust2_out/KO_predicted.tsv.gz --observed_trait_table /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/prokaryotic/ko.txt.gz --hsp_method pic --edge_exponent 0.5 --seed 100 --processes 6 --verbose
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_0 pic 0.5 FALSE FALSE /tmp/tmpii0p5ghp/predicted_counts.txt /tmp/tmpii0p5ghp/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_1 pic 0.5 FALSE FALSE /tmp/tmp3_swm_k7/predicted_counts.txt /tmp/tmp3_swm_k7/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_2 pic 0.5 FALSE FALSE /tmp/tmp03uw8l80/predicted_counts.txt /tmp/tmp03uw8l80/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_3 pic 0.5 FALSE FALSE /tmp/tmppzs97_z3/predicted_counts.txt /tmp/tmppzs97_z3/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_4 pic 0.5 FALSE FALSE /tmp/tmpyaf2bhmo/predicted_counts.txt /tmp/tmpyaf2bhmo/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_5 pic 0.5 FALSE FALSE /tmp/tmpco83o1zo/predicted_counts.txt /tmp/tmpco83o1zo/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_6 pic 0.5 FALSE FALSE /tmp/tmpfz_8b837/predicted_counts.txt /tmp/tmpfz_8b837/predicted_ci.txt 100
#
#
#
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_7 pic 0.5 FALSE FALSE /tmp/tmpopxcoc49/predicted_counts.txt /tmp/tmpopxcoc49/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_8 pic 0.5 FALSE FALSE /tmp/tmpdwe_ubuj/predicted_counts.txt /tmp/tmpdwe_ubuj/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_9 pic 0.5 FALSE FALSE /tmp/tmprqdg_6s9/predicted_counts.txt /tmp/tmprqdg_6s9/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_10 pic 0.5 FALSE FALSE /tmp/tmpcur7079n/predicted_counts.txt /tmp/tmpcur7079n/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_11 pic 0.5 FALSE FALSE /tmp/tmpnxhcggdw/predicted_counts.txt /tmp/tmpnxhcggdw/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_12 pic 0.5 FALSE FALSE /tmp/tmpkjidnbz8/predicted_counts.txt /tmp/tmpkjidnbz8/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_13 pic 0.5 FALSE FALSE /tmp/tmphl7nya69/predicted_counts.txt /tmp/tmphl7nya69/predicted_ci.txt 100
#
#
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_14 pic 0.5 FALSE FALSE /tmp/tmpo5hyhwx0/predicted_counts.txt /tmp/tmpo5hyhwx0/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_15 pic 0.5 FALSE FALSE /tmp/tmpz1iyuf_b/predicted_counts.txt /tmp/tmpz1iyuf_b/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_16 pic 0.5 FALSE FALSE /tmp/tmpf3a0hgas/predicted_counts.txt /tmp/tmpf3a0hgas/predicted_ci.txt 100
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_17 pic 0.5 FALSE FALSE /tmp/tmpqm_8vuuv/predicted_counts.txt /tmp/tmpqm_8vuuv/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_18 pic 0.5 FALSE FALSE /tmp/tmp0mvlaqp8/predicted_counts.txt /tmp/tmp0mvlaqp8/predicted_ci.txt 100
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_19 pic 0.5 FALSE FALSE /tmp/tmp1jja129k/predicted_counts.txt /tmp/tmp1jja129k/predicted_ci.txt 100
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_20 pic 0.5 FALSE FALSE /tmp/tmpwwdgkbqn/predicted_counts.txt /tmp/tmpwwdgkbqn/predicted_ci.txt 100
#
#
# Rscript /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/Rscripts/castor_hsp.R /tmp/tmpe5gvh6vv/picrust2_out/out.tre /tmp/tmpy0n2ntfn/subset_tab_21 pic 0.5 FALSE FALSE /tmp/tmp61l0spwt/predicted_counts.txt /tmp/tmp61l0spwt/predicted_ci.txt 100
#
#
#
#
#
# Running metagenome pipeline for EC
# metagenome_pipeline.py --input /tmp/tmpe5gvh6vv/intable.biom --function /tmp/tmpe5gvh6vv/picrust2_out/EC_predicted.tsv.gz --min_reads 1 --min_samples 1 --out_dir /tmp/tmpe5gvh6vv/picrust2_out/EC_metagenome_out --max_nsti 2 --marker /tmp/tmpe5gvh6vv/picrust2_out/marker_predicted_and_nsti.tsv.gz
# 1 of 1632 ASVs were above the max NSTI cut-off of 2.0 and were removed from the downstream analyses.
#
# Running metagenome pipeline for KO
# metagenome_pipeline.py --input /tmp/tmpe5gvh6vv/intable.biom --function /tmp/tmpe5gvh6vv/picrust2_out/KO_predicted.tsv.gz --min_reads 1 --min_samples 1 --out_dir /tmp/tmpe5gvh6vv/picrust2_out/KO_metagenome_out --max_nsti 2 --marker /tmp/tmpe5gvh6vv/picrust2_out/marker_predicted_and_nsti.tsv.gz
# Inferring pathways from predicted EC
# 1 of 1632 ASVs were above the max NSTI cut-off of 2.0 and were removed from the downstream analyses.
#
# pathway_pipeline.py --input /tmp/tmpe5gvh6vv/picrust2_out/EC_metagenome_out/pred_metagenome_unstrat.tsv.gz --out_dir /tmp/tmpe5gvh6vv/picrust2_out/pathways_out --map /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/pathway_mapfiles/metacyc_path2rxn_struc_filt_pro.txt --intermediate /tmp/tmpe5gvh6vv/picrust2_out/intermediate/pathways --proc 6 --regroup_map /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/picrust2/default_files/pathway_mapfiles/ec_level4_to_metacyc_rxn.tsv --verbose
#
# Wrote predicted pathway abundances and coverages to /tmp/tmpe5gvh6vv/picrust2_out/pathways_out

# %% [markdown]
# ### Persist created artifacts
#
# We will define file paths and persist all artifacts. We start with `.qza` files. We will save the visualization files in sequence as `qzv` files. Finally, we save a `biom`-like file as `tsv` with brief descriptions of all functions.

# %%
if need_pipeline:
    # Export artifact folder
    ec_metagenome.export_data(output_dir=ec_path.split('.')[0])
    ko_metagenome.export_data(output_dir=ko_path.split('.')[0])
    pathway_abundance.export_data(output_dir=pathway_path.split('.')[0])
    
    # Save artifacts as .qza files
    ec_metagenome.save(ec_path)
    ko_metagenome.save(ko_path)
    pathway_abundance.save(pathway_path)

# %%
need_viz = replace_files
need_viz |= not (os.path.isfile(ec_viz_path) and os.path.isfile(ko_viz_path) and os.path.isfile(pathway_viz_path))
if need_viz:
    # Create visualization artifacts
    ec_viz = summarize(table=ec_metagenome, sample_metadata=metadata_qa).visualization
    ko_viz = summarize(table=ko_metagenome, sample_metadata=metadata_qa).visualization
    path_viz = summarize(table=pathway_abundance, sample_metadata=metadata_qa).visualization

    # Save visualization artifacts as .qzv files
    ec_viz.save(ec_viz_path)
    ko_viz.save(ko_viz_path)
    path_viz.save(pathway_viz_path)
# Out:
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
tables = (ec_metagenome, ko_metagenome, pathway_abundance)
table_types = ('ec', 'ko', 'path')

for i, t in enumerate(tables):
    print(f'Processing {table_types[i]}')
    results = core_metrics(
        table = t,
        sampling_depth = 1,
        metadata = metadata_qa,
        n_jobs = 6,
    )
    emperor_out = os.path.join(picrust2_folder, f'{table_types[i]}-bray_curtis_emperor.qzv')
    results.bray_curtis_emperor.save(emperor_out)
    emperor_out = os.path.join(picrust2_folder, f'{table_types[i]}-jaccard_emperor.qzv')
    results.jaccard_emperor.save(emperor_out)
# Out:
# Processing ec
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/skbio/util/_warning.py:60: UserWarning: observed_otus is deprecated as of 0.6.0.
#   warn(f"{func.__name__} is deprecated as of {ver}.")
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/q2_diversity_lib/skbio/_methods.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   return _shannon(counts, base=np.e) / np.log(
# Processing ko
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/q2_diversity_lib/skbio/_methods.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   return _shannon(counts, base=np.e) / np.log(
# Processing path
# /opt/anaconda3/envs/qiime2-amplicon-2024.5/lib/python3.9/site-packages/q2_diversity_lib/skbio/_methods.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   return _shannon(counts, base=np.e) / np.log(

# %%
need_biom = replace_files
need_biom |= not (os.path.isfile(ec_fpath) and os.path.isfile(ko_fpath) and os.path.isfile(pathway_fpath))
if need_biom:
    # Convert artifact to dataframe - transposed
    df_pathway = pathway_abundance.view(pd.DataFrame).T
    df_ec = ec_metagenome.view(pd.DataFrame).T
    df_ko = ko_metagenome.view(pd.DataFrame).T

    # Write dataframe to a tsv file
    df_pathway.to_csv(pathway_fpath, sep='\t', index=True)
    df_ec.to_csv(ec_fpath, sep='\t', index=True)
    df_ko.to_csv(ko_fpath, sep='\t', index=True)
    
    # Put a new column with descriptions of each function's ID
    # !add_descriptions.py -i {ec_fpath} -m EC -o {ec_desc_fpath}
    # !add_descriptions.py -i {ko_fpath} -m KO -o {ko_desc_fpath}
    # !add_descriptions.py -i {pathway_fpath} -m METACYC -o {pathway_desc_fpath}

# %% [markdown]
# ### Aggregate by sum groups counts
#
# We create new columns with the aggregation of the counts for all groups.

# %%
# Create a new DataFrame with Metadata info
metadata_df = metadata_qa.to_dataframe()
# Select all groups
group_ids = metadata_df[class_col].unique()

# %%
# Iterate over all PICRUST2 files
for f in (ec_desc_fpath, ko_desc_fpath, pathway_desc_fpath):
    # Create new DataFrame to store new data
    df = pd.read_csv(f, sep='\t')
    new_df = pd.DataFrame()
    # Iterate over all groups
    for g in group_ids:
        # Select all IDs from current group
        idx = metadata_df[metadata_df[class_col]==g].index
        # Sum all values from samples of the current group
        tmp = df.loc[:, idx].sum(axis=1)
        # Create a new column with the sum
        new_df[g] = tmp
    # Sum the values of all groups
    new_df['Total'] = new_df.sum(axis=1)
    # Join new columns into the end of the original DataFrame
    new_df = pd.concat([df, new_df])
    # Write joined DataFrame to file - overwrite
    new_df.to_csv(f, index=False, sep='\t')
